# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('List of Countries by Sugarcane Production.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0                   Country      Continent Production (Tons)  \
# 0           0                    Brazil  South America       768.678.382
# 1           1                     India           Asia       348.448.000
# 2           2                     China           Asia       123.059.739
# 3           3                  Thailand           Asia        87.468.496
# 4           4                  Pakistan           Asia        65.450.704
# 5           5                    Mexico  North America        56.446.821
# 6           6                  Colombia  South America        36.951.213
# 7           7                 Australia        Oceania        34.403.004
# 8           8                 Guatemala  North America        33.533.403
# 9           9  United States of America  North America        29.926.210
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# ...

# %%
df.shape
# Out:
# (103, 7)

# %% [markdown]
# # Data Cleaning

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace('.','')
df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace('.','').str.replace(',','.')
df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace('.','')
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].str.replace('.','').str.replace(',','.')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.rename(columns = {'Production (Tons)':'Production(Tons)'},inplace = True)
df.rename(columns = {'Production per Person (Kg)':'Production_per_Person(Kg)'},inplace = True)
df.rename(columns = {'Acreage (Hectare)':'Acreage(Hectare)'},inplace = True)
df.rename(columns = {'Yield (Kg / Hectare':'Yield(Kg/Hectare'},inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield (Kg / Hectare)
# 0                  3668.531         10226205              75167.5
# 1                    260721          4950000              70393.5
# 2                     88287          1675215              73459.1
# 3                  1264.303          1336575              65442.2
# 4                    324219          1130820                57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             1
# Yield (Kg / Hectare)         1
# dtype: int64

# %%
df[df['Acreage(Hectare)'].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production(Tons) Production_per_Person(Kg)  \
# 99          99  Djibouti    Africa               53                        51
#
#    Acreage(Hectare) Yield (Kg / Hectare)
# 99              NaN                  NaN

# %%
df=df.dropna().reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0   Country      Continent Production(Tons)  \
# 0      0           0    Brazil  South America        768678382
# 1      1           1     India           Asia        348448000
# 2      2           2     China           Asia        123059739
# 3      3           3  Thailand           Asia         87468496
# 4      4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield (Kg / Hectare)
# 0                  3668.531         10226205              75167.5
# 1                    260721          4950000              70393.5
# 2                     88287          1675215              73459.1
# 3                  1264.303          1336575              65442.2
# 4                    324219          1130820                57879

# %%
df.drop(['index','Unnamed: 0'],axis = 1,inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield (Kg / Hectare)
# 0         10226205              75167.5
# 1          4950000              70393.5
# 2          1675215              73459.1
# 3          1336575              65442.2
# 4          1130820                57879

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_Person(Kg)    object
# Acreage(Hectare)             object
# Yield (Kg / Hectare)         object
# dtype: object

# %%
df['Production(Tons)']=df['Production(Tons)'].astype(float)
df['Production_per_Person(Kg)']=df['Production_per_Person(Kg)'].astype(float)
df['Acreage(Hectare)']=df['Acreage(Hectare)'].astype(float)
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].astype(float)

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield (Kg / Hectare)         float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield (Kg / Hectare)         102
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield (Kg / Hectare)
# 0        10226205.0               75167.5
# 1         4950000.0               70393.5
# 2         1675215.0               73459.1
# 3         1336575.0               65442.2
# 4         1130820.0               57879.0

# %% [markdown]
# ## How many countries produce sugarcane from each continent?

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df['Continent'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## Checking Outliers

# %%
plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
sns.boxplot(df['Production(Tons)'])
plt.subplot(2,2,2)
sns.boxplot(df['Production_per_Person(Kg)'])
plt.subplot(2,2,3)
sns.boxplot(df['Acreage(Hectare)'])
plt.subplot(2,2,4)
sns.boxplot(df['Yield (Kg / Hectare)'])
# Out:
# <Axes: ylabel='Yield (Kg / Hectare)'>

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield (Kg / Hectare)
# count            102.000000
# mean           52628.078431
# std            30504.676683
# min               10.000000
# 25%            29072.025000
# 50%            54108.950000
# 75%            73282.700000
# max           129049.300000

# %% [markdown]
# # Bivariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield (Kg / Hectare)
# 0        10226205.0               75167.5
# 1         4950000.0               70393.5
# 2         1675215.0               73459.1
# 3         1336575.0               65442.2
# 4         1130820.0               57879.0

# %% [markdown]
# ## Which Country Produces maximum sugarcane?

# %%
df_new = df[['Country','Production(Tons)']].set_index('Country')

# %%
df_new['Production(Tons)_percent']=df_new['Production(Tons)']*100/df_new['Production(Tons)'].sum()

# %%
df_new
# Out:
#            Production(Tons)  Production(Tons)_percent
# Country
# Brazil          768678382.0              4.072729e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Spain                 394.0              2.087551e-05
# Lebanon                97.0              5.139401e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new['Production(Tons)_percent'].plot(kind='pie',autopct='%2f')
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df_new['Production(Tons)'].head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
ax = sns.barplot(data = df.head(10) , x='Country',y='Production(Tons)', palette='husl')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_14040\4171368449.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data = df.head(10) , x='Country',y='Production(Tons)', palette='husl')
# C:\Users\anura\AppData\Local\Temp\ipykernel_14040\4171368449.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# ## Which country has the highest land

# %%
df_acr = df.sort_values("Acreage(Hectare)", ascending = False)
ax = sns.barplot(data = df_acr.head(10) , x='Country',y='Acreage(Hectare)',palette='husl')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_14040\2158675609.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data = df_acr.head(10) , x='Country',y='Acreage(Hectare)',palette='husl')
# C:\Users\anura\AppData\Local\Temp\ipykernel_14040\2158675609.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# ## Which country has the highest yeild per hectare?

# %%
df_yld = df.sort_values("Yield (Kg / Hectare)", ascending = False)
ax = sns.barplot(data = df_yld.head(10) , x='Country',y='Yield (Kg / Hectare)',palette='husl')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_14040\1365207210.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data = df_yld.head(10) , x='Country',y='Yield (Kg / Hectare)',palette='husl')
# C:\Users\anura\AppData\Local\Temp\ipykernel_14040\1365207210.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# ## Which country has the highest prpduction

# %%
df_product = df.sort_values("Production(Tons)", ascending = False)
ax = sns.barplot(data = df_product.head(10) , x='Country',y="Production(Tons)",palette='husl')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_14040\4054736143.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data = df_product.head(10) , x='Country',y="Production(Tons)",palette='husl')
# C:\Users\anura\AppData\Local\Temp\ipykernel_14040\4054736143.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# ## Correlation

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df.corr()
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_Person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield (Kg / Hectare)               0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield (Kg / Hectare)
# Production(Tons)                   0.997550              0.132812
# Production_per_Person(Kg)          0.012557              0.017999
# Acreage(Hectare)                   1.000000              0.113433
# Yield (Kg / Hectare)               0.113433              1.000000

# %%
## checkig coorelation using heat map

sns.heatmap(numeric_df.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Do countries with highest land prodce more sugarcane?

# %%
sns.scatterplot(data = df , x= 'Acreage(Hectare)', y='Production(Tons)' )
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ## Do countries which yeild more sugarcane per hectare producees more sugarcane in total?

# %%
sns.scatterplot(data = df , y= 'Acreage(Hectare)', x='Yield (Kg / Hectare)' )
# Out:
# <Axes: xlabel='Yield (Kg / Hectare)', ylabel='Acreage(Hectare)'>

# %% [markdown]
# ## Analysis for Continent

# %%
df_continent = df.groupby("Continent").sum()

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# ...

# %% [markdown]
# ## Which continent produces maximum sugarcane?

# %%
df_continent["Production(Tons)"].sort_values(ascending = False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## Do number of countries in a Continent effects production

# %%
df_continent["number_of_countries"] = df.groupby("Continent").count()['Country']

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# ...

# %%
continent_names = df_continent.index.to_list()
ax=sns.lineplot(data = df_continent, x = 'number_of_countries',y = 'Production(Tons)')
ax.set_xticks(df_continent['number_of_countries'],continent_names, rotation=90)

# %% [markdown]
# ## Correlation for continent

# %%
df_continent.select_dtypes(include=['number']).corr()
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production_per_Person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield (Kg / Hectare)               0.091201                   0.542961
# number_of_countries                0.109244                   0.540086
#
#                            Acreage(Hectare)  Yield (Kg / Hectare)  \
# Production(Tons)                   0.994897              0.091201
# Production_per_Person(Kg)          0.463215              0.542961
# Acreage(Hectare)                   1.000000              0.111166
# Yield (Kg / Hectare)               0.111166              1.000000
# number_of_countries                0.132817              0.989712
#
#                            number_of_countries
# Production(Tons)                      0.109244
# ...

# %% [markdown]
# ## Production distribution by continent

# %%
df_continent['Production(Tons)'].plot(kind = 'pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='Production(Tons)'>
